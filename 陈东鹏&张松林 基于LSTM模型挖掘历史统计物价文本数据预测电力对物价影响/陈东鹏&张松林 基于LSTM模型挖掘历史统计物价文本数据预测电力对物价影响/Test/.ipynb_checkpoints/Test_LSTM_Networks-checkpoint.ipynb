# %% [markdown]
# # 用 LSTM 做时间序列预测

# %%
import numpy
import matplotlib.pyplot as plt
import pandas
import math
from keras.utils import print_summary
from keras.models import Sequential
from keras.models import load_model
from keras.layers import Dense, LSTM, BatchNormalization
from sklearn.preprocessing import MinMaxScaler
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error  # 平方绝对误差
from sklearn.metrics import r2_score  # R square

import sys
sys.path.append("..")
from utils.py import data_tools, networks_factory, data_metrics
from utils.py.constants import const
# %matplotlib inline
# Out:
# Using TensorFlow backend.

# %%
# fix random seed for reproducibility
numpy.random.seed(7)

# %% [markdown]
# ## 导入数据

# %%
dataset = data_tools.load_data_from_csv(const.FILENAME_POTATO)
print("# shape: ", dataset.shape)

# plot
plt.plot(dataset)
plt.show()
# Out:
# # shape:  (1734, 1)

# %% [markdown]
# ## 数据转化与处理

# %%
# transform data to be stationary
diff_internal = 1
diff_series = data_tools.difference(dataset, diff_internal)
diff_values = diff_series.values
diff_values = diff_values.reshape(len(diff_values), 1)
print("# shape:", diff_values.shape)
# Out:
# # shape: (1733, 1)

# %%
# rescale values to -1, 1
scaler = data_tools._MinMaxScaler
scaled_values = scaler.fit_transform(diff_values)
# scaled_values = scaled_values.reshape(len(scaled_values), 1)

# test series_to_supervised 1
# scaled_values = diff_values
# Out:
# C:\Users\demo\Anaconda3\envs\tensorflow\lib\site-packages\sklearn\utils\validation.py:595: DataConversionWarning: Data with input dtype object was converted to float64 by MinMaxScaler.
#   warnings.warn(msg, DataConversionWarning)

# %%
# transform into supervised learning problem X, y
n_lag = const.LOOK_BACK
n_seq = const.OUTPUT
supervised = data_tools.series_to_supervised(scaled_values, n_lag, n_seq)
supervised_values = supervised.values
print("# shape:", supervised_values.shape)

# split into train and test sets
n_test = int(len(supervised_values) * (1 - const.TRAIN_SCALE))
train, test = supervised_values[0:-n_test], supervised_values[-n_test:]
print("# train, test length:", len(train), len(test))
print("# length:", len(diff_values) - n_lag == len(train) + len(test))  # single step
# Out:
# # shape: (1713, 21)
# # train, test length: 1371 342
# # length: True

# %%
trainX, trainY = train[:, 0:n_lag], train[:, n_lag:]
testX, testY = test[:, 0:n_lag], test[:, n_lag:]
print(trainX.shape)
print(trainY.shape)
# Out:
# (1371, 20)
# (1371, 1)

# %%
from sklearn.utils import shuffle
from scipy.sparse import coo_matrix

# shuffle train set (include validation set)
trainX_sparse = coo_matrix(trainX)  # sparse matrix
trainX, trainX_sparse, trainY = shuffle(trainX, trainX_sparse, trainY, random_state=0)

# %% [markdown]
# ## 建立 LSTM 模型

# %%
# reshape training into [samples, timesteps, features]
time_steps = n_lag
trainX = numpy.reshape(trainX, (trainX.shape[0], time_steps, trainX.shape[1]//time_steps)) 
testX = numpy.reshape(testX, (testX.shape[0], time_steps, testX.shape[1]//time_steps))
print(testX.shape)
print(testY.shape)
# Out:
# (342, 20, 1)
# (342, 1)

# %%
n_epoch = networks_factory.EPOCHS
n_batch_size = networks_factory.BATCH_SIZE

# define the grid search parameters
n_hidden_layers = [1, 2, 3, 4, 5]
n_neurons = [8, 16, 24, 32, 40, 48, 56, 64]

for i, n_hidden_layer in enumerate(n_hidden_layers):
    print("------------n_hidden_layers: %d---------------" % n_hidden_layer)
    
    for j, n_neuron in enumerate(n_neurons):
        print("---------------n_neurons: %d---------------" % n_neuron)
        
        # create and fit the LSTM network
        s, model = networks_factory.create_lstm_model(lstm_neurons=n_neuron, hidden_layers=n_hidden_layer, 
                                                      lenth=time_steps, dims=1, n_out=1)
        # model = load_model(model_dir + "model.h5")
        model.compile(loss='mean_squared_error', optimizer='adam')
        history = model.fit(trainX, trainY, epochs=n_epoch, batch_size=n_batch_size, validation_split=const.VALIDATION_SCALE,
                            verbose=0, callbacks=[networks_factory.ES])  # verbose：debug信息
        
        # Plot training & validation loss values
        fig = plt.figure()
        plt.plot(history.history['loss'])
        plt.plot(history.history['val_loss'])
        plt.title('Model loss')
        plt.ylabel('Loss')
        plt.xlabel('Epoch')
        plt.legend(['Train', 'Test'], loc='upper left')
        # fig.show()
    
        # make a prediction
        train_predict = model.predict(trainX)
        test_predict = model.predict(testX)
        # invert predictions
        inv_trainP = scaler.inverse_transform(train_predict)
        inv_trainY = scaler.inverse_transform(trainY)
        inv_testP = scaler.inverse_transform(test_predict)
        inv_testY = scaler.inverse_transform(testY)

        # invert trainPredict differencing
        inv_diff_trainPredict = train_predict.copy()
        # inv_diff_trainPredict = trainY.copy()  # test inv_diff's for loop; clear
        for i in range(len(train_predict)):
            index = diff_internal + n_lag + i - 1  # 1 step forward
            inv_diff_trainPredict[i] = dataset[index] + inv_diff_trainPredict[i]
        inv_diff_trainY = dataset[(diff_internal + n_lag):-n_test, :]

        # invert testPredict differencing
        inv_diff_testPredict = test_predict.copy()
        for i in range(len(test_predict)):
            index = -n_test + i - 1  # 1 step forward
            inv_diff_testPredict[i] = dataset[index] + inv_diff_testPredict[i]
        inv_diff_testY = dataset[-n_test:, :]

        # calculate RMSE, MAPE, Dstat
        train_rmse = math.sqrt(mean_squared_error(inv_diff_trainY, inv_diff_trainPredict))
        test_rmse = math.sqrt(mean_squared_error(inv_diff_testY, inv_diff_testPredict))
        print('Train RMSE: %.4f, Test RMSE: %.4f' % (train_rmse, test_rmse))
        train_mape = data_metrics.MAPE(inv_diff_trainY, inv_diff_trainPredict)
        test_mape = data_metrics.MAPE(inv_diff_testY, inv_diff_testPredict)
        print('Train MAPE: %.4f, Test MAPE: %.4f' % (train_mape, test_mape))
        train_ds = data_metrics.Dstat(inv_diff_trainY, inv_diff_trainPredict)
        test_ds = data_metrics.Dstat(inv_diff_testY, inv_diff_testPredict)
        print('Train Dstat: %.4f, Test Dstat: %.4f' % (train_ds, test_ds))
    
print("# All Done!")
# Out:
# ------------n_hidden_layers: 1---------------
# ---------------n_neurons: 8---------------
# Epoch 00172: early stopping
# C:\Users\demo\Anaconda3\envs\tensorflow\lib\site-packages\matplotlib\figure.py:445: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   % get_backend())
# Train RMSE: 0.1239, Test RMSE: 0.0950
# Train MAPE: 0.0335, Test MAPE: 0.0323
# Train Dstat: 0.7766, Test Dstat: 0.7771
# ---------------n_neurons: 16---------------
# Epoch 00187: early stopping
# C:\Users\demo\Anaconda3\envs\tensorflow\lib\site-packages\matplotlib\figure.py:445: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   % get_backend())
# Train RMSE: 0.1243, Test RMSE: 0.0958
# Train MAPE: 0.0339, Test MAPE: 0.0328
# Train Dstat: 0.7766, Test Dstat: 0.7537
# ---------------n_neurons: 24---------------
# Epoch 00127: early stopping
# C:\Users\demo\Anaconda3\envs\tensorflow\lib\site-packages\matplotlib\figure.py:445: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   % get_backend())
# Train RMSE: 0.1295, Test RMSE: 0.0968
# Train MAPE: 0.0360, Test MAPE: 0.0332
# Train Dstat: 0.7759, Test Dstat: 0.7625
# ---------------n_neurons: 32---------------
# Epoch 00150: early stopping
# C:\Users\demo\Anaconda3\envs\tensorflow\lib\site-packages\matplotlib\figure.py:445: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   % get_backend())
# Train RMSE: 0.1296, Test RMSE: 0.0967
# Train MAPE: 0.0355, Test MAPE: 0.0332
# Train Dstat: 0.7774, Test Dstat: 0.7507
# ---------------n_neurons: 40---------------
# Epoch 00125: early stopping
# C:\Users\demo\Anaconda3\envs\tensorflow\lib\site-packages\matplotlib\figure.py:445: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   % get_backend())
# Train RMSE: 0.1292, Test RMSE: 0.0967
# Train MAPE: 0.0353, Test MAPE: 0.0331
# Train Dstat: 0.7818, Test Dstat: 0.7478
# ---------------n_neurons: 48---------------
# Epoch 00152: early stopping
# C:\Users\demo\Anaconda3\envs\tensorflow\lib\site-packages\matplotlib\figure.py:445: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   % get_backend())
# Train RMSE: 0.1320, Test RMSE: 0.0979
# Train MAPE: 0.0360, Test MAPE: 0.0336
# Train Dstat: 0.7759, Test Dstat: 0.7390
# ---------------n_neurons: 56---------------
# Epoch 00128: early stopping
# C:\Users\demo\Anaconda3\envs\tensorflow\lib\site-packages\matplotlib\figure.py:445: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   % get_backend())
# Train RMSE: 0.1310, Test RMSE: 0.0988
# Train MAPE: 0.0368, Test MAPE: 0.0345
# Train Dstat: 0.7788, Test Dstat: 0.7507
# ---------------n_neurons: 64---------------
# Epoch 00136: early stopping
# C:\Users\demo\Anaconda3\envs\tensorflow\lib\site-packages\matplotlib\figure.py:445: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   % get_backend())
# Train RMSE: 0.1282, Test RMSE: 0.0970
# Train MAPE: 0.0353, Test MAPE: 0.0333
# Train Dstat: 0.7781, Test Dstat: 0.7449
# ------------n_hidden_layers: 2---------------
# ---------------n_neurons: 8---------------
# Epoch 00154: early stopping
# C:\Users\demo\Anaconda3\envs\tensorflow\lib\site-packages\matplotlib\figure.py:445: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   % get_backend())
# Train RMSE: 0.1262, Test RMSE: 0.0964
# Train MAPE: 0.0347, Test MAPE: 0.0331
# Train Dstat: 0.7766, Test Dstat: 0.7537
# ---------------n_neurons: 16---------------
# Epoch 00134: early stopping
# C:\Users\demo\Anaconda3\envs\tensorflow\lib\site-packages\matplotlib\figure.py:445: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   % get_backend())
# Train RMSE: 0.1321, Test RMSE: 0.0963
# Train MAPE: 0.0358, Test MAPE: 0.0330
# Train Dstat: 0.7825, Test Dstat: 0.7595
# ---------------n_neurons: 24---------------
# Epoch 00211: early stopping
# C:\Users\demo\Anaconda3\envs\tensorflow\lib\site-packages\matplotlib\figure.py:445: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   % get_backend())
# Train RMSE: 0.1345, Test RMSE: 0.0988
# Train MAPE: 0.0366, Test MAPE: 0.0339
# Train Dstat: 0.7818, Test Dstat: 0.7331
# ---------------n_neurons: 32---------------
# Epoch 00137: early stopping
# C:\Users\demo\Anaconda3\envs\tensorflow\lib\site-packages\matplotlib\figure.py:445: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   % get_backend())
# Train RMSE: 0.1339, Test RMSE: 0.0976
# Train MAPE: 0.0361, Test MAPE: 0.0332
# Train Dstat: 0.7810, Test Dstat: 0.7478
# ---------------n_neurons: 40---------------
# Epoch 00131: early stopping
# C:\Users\demo\Anaconda3\envs\tensorflow\lib\site-packages\matplotlib\figure.py:445: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   % get_backend())
# Train RMSE: 0.1349, Test RMSE: 0.0977
# Train MAPE: 0.0365, Test MAPE: 0.0334
# Train Dstat: 0.7803, Test Dstat: 0.7331
# ---------------n_neurons: 48---------------
# Epoch 00130: early stopping
# C:\Users\demo\Anaconda3\envs\tensorflow\lib\site-packages\matplotlib\figure.py:445: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   % get_backend())
# Train RMSE: 0.1348, Test RMSE: 0.0978
# Train MAPE: 0.0367, Test MAPE: 0.0334
# Train Dstat: 0.7766, Test Dstat: 0.7390
# ---------------n_neurons: 56---------------
# Epoch 00120: early stopping
# C:\Users\demo\Anaconda3\envs\tensorflow\lib\site-packages\matplotlib\figure.py:445: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   % get_backend())
# Train RMSE: 0.1313, Test RMSE: 0.0978
# Train MAPE: 0.0361, Test MAPE: 0.0333
# Train Dstat: 0.7832, Test Dstat: 0.7595
# ---------------n_neurons: 64---------------
# Epoch 00112: early stopping
# C:\Users\demo\Anaconda3\envs\tensorflow\lib\site-packages\matplotlib\figure.py:445: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   % get_backend())
# Train RMSE: 0.1299, Test RMSE: 0.0970
# Train MAPE: 0.0351, Test MAPE: 0.0328
# Train Dstat: 0.7730, Test Dstat: 0.7654
# ------------n_hidden_layers: 3---------------
# ---------------n_neurons: 8---------------
# Epoch 00152: early stopping
# C:\Users\demo\Anaconda3\envs\tensorflow\lib\site-packages\matplotlib\figure.py:445: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   % get_backend())
# Train RMSE: 0.1306, Test RMSE: 0.0976
# Train MAPE: 0.0354, Test MAPE: 0.0333
# Train Dstat: 0.7774, Test Dstat: 0.7419
# ---------------n_neurons: 16---------------
# Epoch 00151: early stopping
# C:\Users\demo\Anaconda3\envs\tensorflow\lib\site-packages\matplotlib\figure.py:445: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   % get_backend())
# Train RMSE: 0.1328, Test RMSE: 0.0995
# Train MAPE: 0.0360, Test MAPE: 0.0336
# Train Dstat: 0.7839, Test Dstat: 0.7302
# ---------------n_neurons: 24---------------
# Epoch 00120: early stopping
# C:\Users\demo\Anaconda3\envs\tensorflow\lib\site-packages\matplotlib\figure.py:445: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   % get_backend())
# Train RMSE: 0.1330, Test RMSE: 0.0958
# Train MAPE: 0.0359, Test MAPE: 0.0326
# Train Dstat: 0.7774, Test Dstat: 0.7507
# ---------------n_neurons: 32---------------
# Epoch 00126: early stopping
# C:\Users\demo\Anaconda3\envs\tensorflow\lib\site-packages\matplotlib\figure.py:445: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   % get_backend())
# Train RMSE: 0.1346, Test RMSE: 0.0974
# Train MAPE: 0.0365, Test MAPE: 0.0330
# Train Dstat: 0.7693, Test Dstat: 0.7507
# ---------------n_neurons: 40---------------
# Epoch 00111: early stopping
# C:\Users\demo\Anaconda3\envs\tensorflow\lib\site-packages\matplotlib\pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# C:\Users\demo\Anaconda3\envs\tensorflow\lib\site-packages\matplotlib\figure.py:445: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   % get_backend())
# Train RMSE: 0.1358, Test RMSE: 0.0999
# Train MAPE: 0.0373, Test MAPE: 0.0341
# Train Dstat: 0.7715, Test Dstat: 0.7361
# ---------------n_neurons: 48---------------
# Epoch 00165: early stopping
# C:\Users\demo\Anaconda3\envs\tensorflow\lib\site-packages\matplotlib\pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# C:\Users\demo\Anaconda3\envs\tensorflow\lib\site-packages\matplotlib\figure.py:445: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   % get_backend())
# Train RMSE: 0.1484, Test RMSE: 0.1078
# Train MAPE: 0.0415, Test MAPE: 0.0375
# Train Dstat: 0.7540, Test Dstat: 0.7537
# ---------------n_neurons: 56---------------
# Epoch 00173: early stopping
# C:\Users\demo\Anaconda3\envs\tensorflow\lib\site-packages\matplotlib\pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# C:\Users\demo\Anaconda3\envs\tensorflow\lib\site-packages\matplotlib\figure.py:445: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   % get_backend())
# Train RMSE: 0.1439, Test RMSE: 0.1015
# Train MAPE: 0.0393, Test MAPE: 0.0351
# Train Dstat: 0.7810, Test Dstat: 0.7390
# ---------------n_neurons: 64---------------
# Epoch 00119: early stopping
# C:\Users\demo\Anaconda3\envs\tensorflow\lib\site-packages\matplotlib\pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# C:\Users\demo\Anaconda3\envs\tensorflow\lib\site-packages\matplotlib\figure.py:445: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   % get_backend())
# Train RMSE: 0.1347, Test RMSE: 0.0975
# Train MAPE: 0.0364, Test MAPE: 0.0326
# Train Dstat: 0.7635, Test Dstat: 0.7361
# ------------n_hidden_layers: 4---------------
# ---------------n_neurons: 8---------------
# Epoch 00169: early stopping
# C:\Users\demo\Anaconda3\envs\tensorflow\lib\site-packages\matplotlib\pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# C:\Users\demo\Anaconda3\envs\tensorflow\lib\site-packages\matplotlib\figure.py:445: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   % get_backend())
# Train RMSE: 0.1359, Test RMSE: 0.0994
# Train MAPE: 0.0376, Test MAPE: 0.0340
# Train Dstat: 0.7686, Test Dstat: 0.7390
# ---------------n_neurons: 16---------------
# Epoch 00150: early stopping
# C:\Users\demo\Anaconda3\envs\tensorflow\lib\site-packages\matplotlib\pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# C:\Users\demo\Anaconda3\envs\tensorflow\lib\site-packages\matplotlib\figure.py:445: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   % get_backend())
# Train RMSE: 0.1345, Test RMSE: 0.0988
# Train MAPE: 0.0372, Test MAPE: 0.0338
# Train Dstat: 0.7701, Test Dstat: 0.7214
# ---------------n_neurons: 24---------------
# Epoch 00139: early stopping
# C:\Users\demo\Anaconda3\envs\tensorflow\lib\site-packages\matplotlib\pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# C:\Users\demo\Anaconda3\envs\tensorflow\lib\site-packages\matplotlib\figure.py:445: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   % get_backend())
# Train RMSE: 0.1378, Test RMSE: 0.0988
# Train MAPE: 0.0381, Test MAPE: 0.0341
# Train Dstat: 0.7788, Test Dstat: 0.7449
# ---------------n_neurons: 32---------------
# Epoch 00128: early stopping
# C:\Users\demo\Anaconda3\envs\tensorflow\lib\site-packages\matplotlib\pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# C:\Users\demo\Anaconda3\envs\tensorflow\lib\site-packages\matplotlib\figure.py:445: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   % get_backend())
# Train RMSE: 0.1366, Test RMSE: 0.0993
# Train MAPE: 0.0375, Test MAPE: 0.0336
# Train Dstat: 0.7825, Test Dstat: 0.7331
# ---------------n_neurons: 40---------------
# Epoch 00137: early stopping
# C:\Users\demo\Anaconda3\envs\tensorflow\lib\site-packages\matplotlib\pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# C:\Users\demo\Anaconda3\envs\tensorflow\lib\site-packages\matplotlib\figure.py:445: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   % get_backend())
# Train RMSE: 0.1405, Test RMSE: 0.0988
# Train MAPE: 0.0388, Test MAPE: 0.0343
# Train Dstat: 0.7708, Test Dstat: 0.7478
# ---------------n_neurons: 48---------------
# Epoch 00143: early stopping
# C:\Users\demo\Anaconda3\envs\tensorflow\lib\site-packages\matplotlib\pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# C:\Users\demo\Anaconda3\envs\tensorflow\lib\site-packages\matplotlib\figure.py:445: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   % get_backend())
# Train RMSE: 0.1454, Test RMSE: 0.1097
# Train MAPE: 0.0414, Test MAPE: 0.0385
# Train Dstat: 0.7686, Test Dstat: 0.7478
# ---------------n_neurons: 56---------------
# Epoch 00134: early stopping
# C:\Users\demo\Anaconda3\envs\tensorflow\lib\site-packages\matplotlib\pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# C:\Users\demo\Anaconda3\envs\tensorflow\lib\site-packages\matplotlib\figure.py:445: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   % get_backend())
# Train RMSE: 0.1410, Test RMSE: 0.1042
# Train MAPE: 0.0401, Test MAPE: 0.0364
# Train Dstat: 0.7788, Test Dstat: 0.7185
# ---------------n_neurons: 64---------------
# Epoch 00133: early stopping
# C:\Users\demo\Anaconda3\envs\tensorflow\lib\site-packages\matplotlib\pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# C:\Users\demo\Anaconda3\envs\tensorflow\lib\site-packages\matplotlib\figure.py:445: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   % get_backend())
# Train RMSE: 0.1431, Test RMSE: 0.1119
# Train MAPE: 0.0406, Test MAPE: 0.0391
# Train Dstat: 0.7723, Test Dstat: 0.7507
# ------------n_hidden_layers: 5---------------
# ---------------n_neurons: 8---------------
# Epoch 00198: early stopping
# C:\Users\demo\Anaconda3\envs\tensorflow\lib\site-packages\matplotlib\pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# C:\Users\demo\Anaconda3\envs\tensorflow\lib\site-packages\matplotlib\figure.py:445: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   % get_backend())
# Train RMSE: 0.1315, Test RMSE: 0.1038
# Train MAPE: 0.0373, Test MAPE: 0.0354
# Train Dstat: 0.7628, Test Dstat: 0.7273
# ---------------n_neurons: 16---------------
# Epoch 00182: early stopping
# C:\Users\demo\Anaconda3\envs\tensorflow\lib\site-packages\matplotlib\pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# C:\Users\demo\Anaconda3\envs\tensorflow\lib\site-packages\matplotlib\figure.py:445: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   % get_backend())
# Train RMSE: 0.1446, Test RMSE: 0.1073
# Train MAPE: 0.0411, Test MAPE: 0.0368
# Train Dstat: 0.7752, Test Dstat: 0.7449
# ---------------n_neurons: 24---------------
# Epoch 00177: early stopping
# C:\Users\demo\Anaconda3\envs\tensorflow\lib\site-packages\matplotlib\pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# C:\Users\demo\Anaconda3\envs\tensorflow\lib\site-packages\matplotlib\figure.py:445: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   % get_backend())
# Train RMSE: 0.1564, Test RMSE: 0.1205
# Train MAPE: 0.0457, Test MAPE: 0.0418
# Train Dstat: 0.7803, Test Dstat: 0.7507
# ---------------n_neurons: 32---------------
# Epoch 00153: early stopping
# C:\Users\demo\Anaconda3\envs\tensorflow\lib\site-packages\matplotlib\pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# C:\Users\demo\Anaconda3\envs\tensorflow\lib\site-packages\matplotlib\figure.py:445: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   % get_backend())
# Train RMSE: 0.1416, Test RMSE: 0.1002
# Train MAPE: 0.0390, Test MAPE: 0.0342
# Train Dstat: 0.7759, Test Dstat: 0.7331
# ---------------n_neurons: 40---------------
# Epoch 00157: early stopping
# C:\Users\demo\Anaconda3\envs\tensorflow\lib\site-packages\matplotlib\pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# C:\Users\demo\Anaconda3\envs\tensorflow\lib\site-packages\matplotlib\figure.py:445: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   % get_backend())
# Train RMSE: 0.1564, Test RMSE: 0.1187
# Train MAPE: 0.0454, Test MAPE: 0.0412
# Train Dstat: 0.7730, Test Dstat: 0.7185
# ---------------n_neurons: 48---------------
# Epoch 00145: early stopping
# C:\Users\demo\Anaconda3\envs\tensorflow\lib\site-packages\matplotlib\pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# C:\Users\demo\Anaconda3\envs\tensorflow\lib\site-packages\matplotlib\figure.py:445: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   % get_backend())
# Train RMSE: 0.1485, Test RMSE: 0.1140
# Train MAPE: 0.0433, Test MAPE: 0.0404
# Train Dstat: 0.7752, Test Dstat: 0.7273
# ---------------n_neurons: 56---------------
# Epoch 00144: early stopping
# C:\Users\demo\Anaconda3\envs\tensorflow\lib\site-packages\matplotlib\pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# C:\Users\demo\Anaconda3\envs\tensorflow\lib\site-packages\matplotlib\figure.py:445: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   % get_backend())
# Train RMSE: 0.1647, Test RMSE: 0.1327
# Train MAPE: 0.0482, Test MAPE: 0.0465
# Train Dstat: 0.7745, Test Dstat: 0.7155
# ---------------n_neurons: 64---------------
# Epoch 00143: early stopping
# C:\Users\demo\Anaconda3\envs\tensorflow\lib\site-packages\matplotlib\pyplot.py:514: RuntimeWarning: More than 20 figures have been opened. Figures created through the pyplot interface (`matplotlib.pyplot.figure`) are retained until explicitly closed and may consume too much memory. (To control this warning, see the rcParam `figure.max_open_warning`).
#   max_open_warning, RuntimeWarning)
# C:\Users\demo\Anaconda3\envs\tensorflow\lib\site-packages\matplotlib\figure.py:445: UserWarning: Matplotlib is currently using module://ipykernel.pylab.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   % get_backend())
# Train RMSE: 0.1657, Test RMSE: 0.1235
# Train MAPE: 0.0490, Test MAPE: 0.0417
# Train Dstat: 0.7708, Test Dstat: 0.7302
# # All Done!

# %% [markdown]
# 参考：[Time Series Prediction with LSTM Recurrent Neural Networks in Python with Keras](https://machinelearningmastery.com/time-series-prediction-lstm-recurrent-neural-networks-python-keras/"Title")
