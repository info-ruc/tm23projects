# %%
import numpy as np
import pandas
import pylab as plt  # matplotlib的一个子包
from sklearn.preprocessing import MinMaxScaler
from math import sqrt
from sklearn.utils import shuffle
from scipy.sparse import coo_matrix
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error # 平方绝对误差
from sklearn.metrics import r2_score  # R square

import sys                    #导入sys模块
sys.path.append(r'C:/Users/demo/workplace/Time-Series-Prediction-with-LSTM/')  # 要用绝对路径
from utils import eemd_tools, data_tools, networks_factory, data_metrics
from utils.constants import const
# Out:
# Using TensorFlow backend.

# %%
# fix random seed for reproducibility
np.random.seed(7)

# %% [markdown]
# # 导入数据

# %%
dataset = eemd_tools.load_data_to_signal(const.DATA_DIR + "apple_interpolate.csv")
times = np.arange(len(dataset))  # or dataset.shape[0]
print("s's shape: ", dataset.shape)
print("t's lenth: ", times.shape)
print(dataset)
print(times)
# Out:
# s's shape:  (1901,)
# t's lenth:  (1901,)
# [10.71 10.71 10.71 ...  9.5   9.5   9.5 ]
# [   0    1    2 ... 1898 1899 1900]

# %%
# Plot original series
plt.plot(times, dataset, 'r')
plt.title("Input signal:")
plt.xlabel("Time [s]")
plt.show()

# %% [markdown]
# # EEMD

# %%
data_multi, vis_de, vis_re, df_ttest = eemd_tools.singal_to_supervised(dataset)
print("# singal_to_supervised() done.")
# Out:
# # index:  5
# test fine_to_coarse(imfs)
#  [-0.32714492  0.40368015  0.34997376 ... -0.27305577  0.74338977
#   0.27146957]
# # singal_to_supervised() done.

# %%
# pitures saved by hand.
# vis_de.save(const.PROJECT_DIR + "data/eemd/pig0317/decompose.jpg")
# vis_re.save(const.PROJECT_DIR + "data/eemd/pig0317/reconsitution.jpg")
df_ttest.to_excel(const.PROJECT_DIR + "data/eemd/apple/t-test.xls")
np.save(const.PROJECT_DIR + "data/eemd/apple0323/data_multi.npy", data_multi)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-aa4aebad8d87> in <module>
#       2 # vis_de.save(const.PROJECT_DIR + "data/eemd/pig0317/decompose.jpg")
#       3 # vis_re.save(const.PROJECT_DIR + "data/eemd/pig0317/reconsitution.jpg")
# ----> 4 df_ttest.to_excel(const.PROJECT_DIR + "data/eemd/apple0323/t-test.xls")
#       5 np.save(const.PROJECT_DIR + "data/eemd/apple0323/data_multi.npy", data_multi)
#
# ~\Anaconda3\envs\tensorflow\lib\site-packages\pandas\core\frame.py in to_excel(self, excel_writer, sheet_name, na_rep, float_format, columns, header, index, index_label, startrow, startcol, engine, merge_cells, encoding, inf_rep, verbose, freeze_panes)
#    1764         formatter.write(excel_writer, sheet_name=sheet_name, startrow=startrow,
#    1765                         startcol=startcol, freeze_panes=freeze_panes,
# ...

# %%
b = np.load(const.PROJECT_DIR + "data/eemd/apple0323/data_multi.npy")
print("# shape", b.shape)  # not .shape()
print(b)

# %%
print((data_multi == b).any())
