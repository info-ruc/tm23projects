# %%
import numpy as np
import pandas
import pylab as plt  # matplotlib的一个子包
from sklearn.preprocessing import MinMaxScaler
from math import sqrt
from sklearn.utils import shuffle
from scipy.sparse import coo_matrix
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error # 平方绝对误差
from sklearn.metrics import r2_score  # R square

import sys 
sys.path.append(r'C:\\Users\\demo\\workplace\\Time-Series-Prediction-with-LSTM\\')  # 要用绝对路径
from utils import eemd_tools, data_tools, networks_factory, data_metrics
from utils.constants import const

# %%
# fix random seed for reproducibility
np.random.seed(7)

# %% [markdown]
# # 导入数据

# %%
data_multi = np.load(const.PROJECT_DIR + "data/eemd/apple/data_multi.npy")
print("# shape", data_multi.shape)  # not .shape()
# Out:
# # shape (1901, 4)

# %% [markdown]
# ## data preprocessing; (-1, 1)

# %%
# normalize features
scaler = MinMaxScaler(feature_range=(-1, 1))
scaled = scaler.fit_transform(data_multi)

output = 1

lags = [5, 7, 9, 11, 13, 15, 17, 19, 21]
# lags = [5, 10, 15, 20, 25, 30, 35, 40]
# lags = [10, 20, 30, 40, 50, 60]
# lags = [10]  # test one

multi_data_supervised = list()
for i, lag in enumerate(lags):
    reframed = data_tools.series_to_supervised(scaled, lag, output)
    # drop columns we don't want to predict
    index_drop = [-j-1 for j in range(data_multi.shape[1] - 1)]
    reframed.drop(reframed.columns[index_drop], axis=1, inplace=True)
    data_supervised = reframed.values
    multi_data_supervised.append(data_supervised)
    print("# shape:", reframed.shape)
    print(len(data_multi) == len(reframed) + lag)
    # print(reframed.head(3))

print("-----------done--------------")
print(len(multi_data_supervised))
# Out:
# # shape: (1896, 21)
# True
# # shape: (1894, 29)
# True
# # shape: (1892, 37)
# True
# # shape: (1890, 45)
# True
# # shape: (1888, 53)
# True
# # shape: (1886, 61)
# True
# # shape: (1884, 69)
# True
# # shape: (1882, 77)
# True
# # shape: (1880, 85)
# True
# -----------done--------------
# 9

# %% [markdown]
# # LSTM

# %%
n_lstm_neurons = [4, 8, 16, 24, 32, 40, 48]
# n_lstm_neurons = 32
n_epoch = networks_factory.EPOCHS
n_batch_size = networks_factory.BATCH_SIZE

# %% [markdown]
# ## test set is for validate; hidden_layers=1

# %%
for i, data_supervised in enumerate(multi_data_supervised):
    # split into train and test sets
    train_size = int(len(data_supervised) * 0.80)
    test_size = len(data_supervised) - train_size
    train_data, test_data = data_supervised[0:train_size,:], data_supervised[train_size:len(data_multi),:]
    
    # split into input and outputs
    train_X, train_Y = train_data[:, :-1], train_data[:, -1]
    test_X, test_Y = test_data[:, :-1], test_data[:, -1]
 
    # reshape input to be 3D [samples, timesteps, features]
    time_steps = lags[i]  # There are dependencies
    print("-----------time steps: %d--------------" % time_steps)
    train_X = train_X.reshape((train_X.shape[0], time_steps, train_X.shape[1]//time_steps))
    test_X = test_X.reshape((test_X.shape[0], time_steps, test_X.shape[1]//time_steps))
    
    for i, n_lstm_neuron in enumerate(n_lstm_neurons):
        print("-----------n_lstm_neuron: %d--------------" % n_lstm_neuron)
        # create and fit the LSTM network
        n_dims = train_X.shape[2]
        s, model = networks_factory.create_lstm_model(lstm_neurons=n_lstm_neuron, hidden_layers=1, 
                                                      lenth=time_steps, dims=n_dims, n_out=1)

        model.compile(loss='mae', optimizer='adam')
        # fit network
        history = model.fit(train_X, train_Y, epochs=n_epoch, batch_size=n_batch_size, validation_data=(test_X, test_Y), 
                            verbose=0, callbacks=[networks_factory.ES])
        print("# Finished Training...")

        # make a prediction
        train_predict = model.predict(train_X)
        test_predict = model.predict(test_X)
        # invert predictions
        inv_trainP, inv_trainY = data_tools.inv_transform_multi(scaler, train_X, train_predict, train_Y)
        inv_testP, inv_testY = data_tools.inv_transform_multi(scaler, test_X, test_predict, test_Y)

        # calculate RMSE, MAPE, Dstat
        train_rmse = sqrt(mean_squared_error(inv_trainP, inv_trainY))
        test_rmse = sqrt(mean_squared_error(inv_testP, inv_testY))
        print('Train RMSE: %.4f, Test RMSE: %.4f' % (train_rmse, test_rmse))
        train_mape = data_metrics.MAPE(inv_trainP, inv_trainY)
        test_mape = data_metrics.MAPE(inv_testP, inv_testY)
        print('Train MAPE: %.4f, Test MAPE: %.4f' % (train_mape, test_mape))
        train_ds = data_metrics.Dstat(inv_trainP, inv_trainY)
        test_ds = data_metrics.Dstat(inv_testP, inv_testY)
        print('Train Dstat: %.4f, Test Dstat: %.4f' % (train_ds, test_ds))
        
    print("")

print("# All Done!")
# Out:
# -----------time steps: 5--------------
# -----------n_lstm_neuron: 4--------------
# Epoch 00286: early stopping
# # Finished Training...
# Train RMSE: 0.5640, Test RMSE: 0.2283
# Train MAPE: 0.0300, Test MAPE: 0.0189
# Train Dstat: 0.7122, Test Dstat: 0.8285
# -----------n_lstm_neuron: 8--------------
# Epoch 00352: early stopping
# # Finished Training...
# Train RMSE: 0.5698, Test RMSE: 0.2324
# Train MAPE: 0.0321, Test MAPE: 0.0200
# Train Dstat: 0.6997, Test Dstat: 0.7678
# -----------n_lstm_neuron: 16--------------
# Epoch 00281: early stopping
# # Finished Training...
# Train RMSE: 0.5600, Test RMSE: 0.2413
# Train MAPE: 0.0304, Test MAPE: 0.0212
# Train Dstat: 0.7149, Test Dstat: 0.7203
# -----------n_lstm_neuron: 24--------------
# Epoch 00291: early stopping
# # Finished Training...
# Train RMSE: 0.5687, Test RMSE: 0.3152
# Train MAPE: 0.0331, Test MAPE: 0.0322
# Train Dstat: 0.7003, Test Dstat: 0.6781
# -----------n_lstm_neuron: 32--------------
# Epoch 00232: early stopping
# # Finished Training...
# Train RMSE: 0.6641, Test RMSE: 0.3909
# Train MAPE: 0.0492, Test MAPE: 0.0444
# Train Dstat: 0.6521, Test Dstat: 0.6675
# -----------n_lstm_neuron: 40--------------
# Epoch 00284: early stopping
# # Finished Training...
# Train RMSE: 0.5808, Test RMSE: 0.3077
# Train MAPE: 0.0346, Test MAPE: 0.0313
# Train Dstat: 0.7135, Test Dstat: 0.7098
# -----------n_lstm_neuron: 48--------------
# Epoch 00238: early stopping
# # Finished Training...
# Train RMSE: 0.5740, Test RMSE: 0.2402
# Train MAPE: 0.0327, Test MAPE: 0.0206
# Train Dstat: 0.7083, Test Dstat: 0.7916
#
# -----------time steps: 7--------------
# -----------n_lstm_neuron: 4--------------
# Epoch 00358: early stopping
# # Finished Training...
# Train RMSE: 0.5671, Test RMSE: 0.2326
# Train MAPE: 0.0312, Test MAPE: 0.0200
# Train Dstat: 0.7067, Test Dstat: 0.7884
# -----------n_lstm_neuron: 8--------------
# Epoch 00268: early stopping
# # Finished Training...
# Train RMSE: 0.5742, Test RMSE: 0.3122
# Train MAPE: 0.0334, Test MAPE: 0.0336
# Train Dstat: 0.7107, Test Dstat: 0.6746
# -----------n_lstm_neuron: 16--------------
# Epoch 00316: early stopping
# # Finished Training...
# Train RMSE: 0.5780, Test RMSE: 0.2467
# Train MAPE: 0.0339, Test MAPE: 0.0226
# Train Dstat: 0.7338, Test Dstat: 0.7698
# -----------n_lstm_neuron: 24--------------
# Epoch 00288: early stopping
# # Finished Training...
# Train RMSE: 0.5689, Test RMSE: 0.2539
# Train MAPE: 0.0324, Test MAPE: 0.0245
# Train Dstat: 0.7173, Test Dstat: 0.7116
# -----------n_lstm_neuron: 32--------------
# Epoch 00266: early stopping
# # Finished Training...
# Train RMSE: 0.5675, Test RMSE: 0.2394
# Train MAPE: 0.0320, Test MAPE: 0.0208
# Train Dstat: 0.7299, Test Dstat: 0.7725
# -----------n_lstm_neuron: 40--------------
# Epoch 00269: early stopping
# # Finished Training...
# Train RMSE: 0.5722, Test RMSE: 0.2545
# Train MAPE: 0.0317, Test MAPE: 0.0227
# Train Dstat: 0.7054, Test Dstat: 0.7619
# -----------n_lstm_neuron: 48--------------
# Epoch 00257: early stopping
# # Finished Training...
# Train RMSE: 0.5838, Test RMSE: 0.3067
# Train MAPE: 0.0335, Test MAPE: 0.0313
# Train Dstat: 0.7292, Test Dstat: 0.6852
#
# -----------time steps: 9--------------
# -----------n_lstm_neuron: 4--------------
# Epoch 00282: early stopping
# # Finished Training...
# Train RMSE: 0.5892, Test RMSE: 0.3391
# Train MAPE: 0.0349, Test MAPE: 0.0357
# Train Dstat: 0.6832, Test Dstat: 0.6349
# -----------n_lstm_neuron: 8--------------
# Epoch 00385: early stopping
# # Finished Training...
# Train RMSE: 0.5703, Test RMSE: 0.2326
# Train MAPE: 0.0312, Test MAPE: 0.0205
# Train Dstat: 0.7123, Test Dstat: 0.7593
# -----------n_lstm_neuron: 16--------------
# Epoch 00298: early stopping
# # Finished Training...
# Train RMSE: 0.6050, Test RMSE: 0.3495
# Train MAPE: 0.0380, Test MAPE: 0.0379
# Train Dstat: 0.6660, Test Dstat: 0.6111
# -----------n_lstm_neuron: 24--------------
# Epoch 00239: early stopping
# # Finished Training...
# Train RMSE: 0.5730, Test RMSE: 0.2358
# Train MAPE: 0.0340, Test MAPE: 0.0211
# Train Dstat: 0.7176, Test Dstat: 0.7778
# -----------n_lstm_neuron: 32--------------
# Epoch 00329: early stopping
# # Finished Training...
# Train RMSE: 0.5529, Test RMSE: 0.2618
# Train MAPE: 0.0306, Test MAPE: 0.0249
# Train Dstat: 0.7216, Test Dstat: 0.6984
# -----------n_lstm_neuron: 40--------------
# Epoch 00352: early stopping
# # Finished Training...
# Train RMSE: 0.5720, Test RMSE: 0.2233
# Train MAPE: 0.0336, Test MAPE: 0.0190
# Train Dstat: 0.6918, Test Dstat: 0.7989
# -----------n_lstm_neuron: 48--------------
# Epoch 00333: early stopping
# # Finished Training...
# Train RMSE: 0.5439, Test RMSE: 0.2332
# Train MAPE: 0.0307, Test MAPE: 0.0202
# Train Dstat: 0.7368, Test Dstat: 0.7884
#
# -----------time steps: 11--------------
# -----------n_lstm_neuron: 4--------------
# Epoch 00383: early stopping
# # Finished Training...
# Train RMSE: 0.5613, Test RMSE: 0.2287
# Train MAPE: 0.0298, Test MAPE: 0.0182
# Train Dstat: 0.7267, Test Dstat: 0.8170
# -----------n_lstm_neuron: 8--------------
# Epoch 00301: early stopping
# # Finished Training...
# Train RMSE: 0.5615, Test RMSE: 0.2326
# Train MAPE: 0.0306, Test MAPE: 0.0198
# Train Dstat: 0.7062, Test Dstat: 0.7586
# -----------n_lstm_neuron: 16--------------
# Epoch 00325: early stopping
# # Finished Training...
# Train RMSE: 0.5708, Test RMSE: 0.2281
# Train MAPE: 0.0316, Test MAPE: 0.0187
# Train Dstat: 0.7386, Test Dstat: 0.7772
# -----------n_lstm_neuron: 24--------------
# Epoch 00243: early stopping
# # Finished Training...
# Train RMSE: 0.5803, Test RMSE: 0.3023
# Train MAPE: 0.0371, Test MAPE: 0.0320
# Train Dstat: 0.6856, Test Dstat: 0.6552
# -----------n_lstm_neuron: 32--------------
# Epoch 00247: early stopping
# # Finished Training...
# Train RMSE: 0.5549, Test RMSE: 0.2322
# Train MAPE: 0.0306, Test MAPE: 0.0198
# Train Dstat: 0.7081, Test Dstat: 0.7931
# -----------n_lstm_neuron: 40--------------
# Epoch 00315: early stopping
# # Finished Training...
# Train RMSE: 0.5525, Test RMSE: 0.2408
# Train MAPE: 0.0302, Test MAPE: 0.0211
# Train Dstat: 0.7439, Test Dstat: 0.7745
# -----------n_lstm_neuron: 48--------------
# Epoch 00251: early stopping
# # Finished Training...
# Train RMSE: 0.6275, Test RMSE: 0.3951
# Train MAPE: 0.0469, Test MAPE: 0.0460
# Train Dstat: 0.6757, Test Dstat: 0.6180
#
# -----------time steps: 13--------------
# -----------n_lstm_neuron: 4--------------
# Epoch 00298: early stopping
# # Finished Training...
# Train RMSE: 0.5782, Test RMSE: 0.3043
# Train MAPE: 0.0360, Test MAPE: 0.0313
# Train Dstat: 0.6759, Test Dstat: 0.6764
# -----------n_lstm_neuron: 8--------------
# Epoch 00248: early stopping
# # Finished Training...
# Train RMSE: 0.5753, Test RMSE: 0.2640
# Train MAPE: 0.0319, Test MAPE: 0.0255
# Train Dstat: 0.7230, Test Dstat: 0.7454
# -----------n_lstm_neuron: 16--------------
# Epoch 00243: early stopping
# # Finished Training...
# Train RMSE: 0.5835, Test RMSE: 0.2437
# Train MAPE: 0.0349, Test MAPE: 0.0217
# Train Dstat: 0.7223, Test Dstat: 0.7480
# -----------n_lstm_neuron: 24--------------
# Epoch 00258: early stopping
# # Finished Training...
# Train RMSE: 0.5557, Test RMSE: 0.3076
# Train MAPE: 0.0319, Test MAPE: 0.0313
# Train Dstat: 0.7064, Test Dstat: 0.6578
# -----------n_lstm_neuron: 32--------------
# Epoch 00272: early stopping
# # Finished Training...
# Train RMSE: 0.5754, Test RMSE: 0.2317
# Train MAPE: 0.0333, Test MAPE: 0.0202
# Train Dstat: 0.7170, Test Dstat: 0.7878
# -----------n_lstm_neuron: 40--------------
# Epoch 00292: early stopping
# # Finished Training...
# Train RMSE: 0.5554, Test RMSE: 0.2332
# Train MAPE: 0.0303, Test MAPE: 0.0204
# Train Dstat: 0.7515, Test Dstat: 0.7692
# -----------n_lstm_neuron: 48--------------
# Epoch 00241: early stopping
# # Finished Training...
# Train RMSE: 0.5689, Test RMSE: 0.2505
# Train MAPE: 0.0330, Test MAPE: 0.0226
# Train Dstat: 0.7237, Test Dstat: 0.7215
#
# -----------time steps: 15--------------
# -----------n_lstm_neuron: 4--------------
# Epoch 00312: early stopping
# # Finished Training...
# Train RMSE: 0.5970, Test RMSE: 0.4014
# Train MAPE: 0.0402, Test MAPE: 0.0438
# Train Dstat: 0.6676, Test Dstat: 0.6101
# -----------n_lstm_neuron: 8--------------
# Epoch 00434: early stopping
# # Finished Training...
# Train RMSE: 0.5696, Test RMSE: 0.2452
# Train MAPE: 0.0325, Test MAPE: 0.0233
# Train Dstat: 0.7060, Test Dstat: 0.7188
# -----------n_lstm_neuron: 16--------------
# Epoch 00269: early stopping
# # Finished Training...
# Train RMSE: 0.5881, Test RMSE: 0.2508
# Train MAPE: 0.0347, Test MAPE: 0.0228
# Train Dstat: 0.6768, Test Dstat: 0.7056
# -----------n_lstm_neuron: 24--------------
# Epoch 00283: early stopping
# # Finished Training...
# Train RMSE: 0.5609, Test RMSE: 0.2450
# Train MAPE: 0.0300, Test MAPE: 0.0226
# Train Dstat: 0.7213, Test Dstat: 0.7427
# -----------n_lstm_neuron: 32--------------
# Epoch 00229: early stopping
# # Finished Training...
# Train RMSE: 0.5600, Test RMSE: 0.2433
# Train MAPE: 0.0303, Test MAPE: 0.0222
# Train Dstat: 0.7299, Test Dstat: 0.7480
# -----------n_lstm_neuron: 40--------------
# Epoch 00293: early stopping
# # Finished Training...
# Train RMSE: 0.5665, Test RMSE: 0.2916
# Train MAPE: 0.0338, Test MAPE: 0.0294
# Train Dstat: 0.6855, Test Dstat: 0.6631
# -----------n_lstm_neuron: 48--------------
# Epoch 00257: early stopping
# # Finished Training...
# Train RMSE: 0.5860, Test RMSE: 0.2861
# Train MAPE: 0.0354, Test MAPE: 0.0287
# Train Dstat: 0.7339, Test Dstat: 0.7401
#
# -----------time steps: 17--------------
# -----------n_lstm_neuron: 4--------------
# Epoch 00290: early stopping
# # Finished Training...
# Train RMSE: 0.5714, Test RMSE: 0.2231
# Train MAPE: 0.0307, Test MAPE: 0.0186
# Train Dstat: 0.7271, Test Dstat: 0.7926
# -----------n_lstm_neuron: 8--------------
# Epoch 00331: early stopping
# # Finished Training...
# Train RMSE: 0.6013, Test RMSE: 0.2796
# Train MAPE: 0.0394, Test MAPE: 0.0279
# Train Dstat: 0.7105, Test Dstat: 0.7420
# -----------n_lstm_neuron: 16--------------
# Epoch 00341: early stopping
# # Finished Training...
# Train RMSE: 0.5507, Test RMSE: 0.2466
# Train MAPE: 0.0297, Test MAPE: 0.0229
# Train Dstat: 0.7304, Test Dstat: 0.7181
# -----------n_lstm_neuron: 24--------------
# Epoch 00311: early stopping
# # Finished Training...
# Train RMSE: 0.5701, Test RMSE: 0.2346
# Train MAPE: 0.0325, Test MAPE: 0.0200
# Train Dstat: 0.7231, Test Dstat: 0.7713
# -----------n_lstm_neuron: 32--------------
# Epoch 00251: early stopping
# # Finished Training...
# Train RMSE: 0.5894, Test RMSE: 0.3772
# Train MAPE: 0.0377, Test MAPE: 0.0416
# Train Dstat: 0.6899, Test Dstat: 0.6303
# -----------n_lstm_neuron: 40--------------
# Epoch 00297: early stopping
# # Finished Training...
# Train RMSE: 0.5539, Test RMSE: 0.2531
# Train MAPE: 0.0307, Test MAPE: 0.0244
# Train Dstat: 0.7218, Test Dstat: 0.7128
# -----------n_lstm_neuron: 48--------------
# Epoch 00309: early stopping
# # Finished Training...
# Train RMSE: 0.5665, Test RMSE: 0.3163
# Train MAPE: 0.0353, Test MAPE: 0.0329
# Train Dstat: 0.6912, Test Dstat: 0.6463
#
# -----------time steps: 19--------------
# -----------n_lstm_neuron: 4--------------
# Epoch 00397: early stopping
# # Finished Training...
# Train RMSE: 0.6636, Test RMSE: 0.2299
# Train MAPE: 0.0400, Test MAPE: 0.0191
# Train Dstat: 0.6616, Test Dstat: 0.7314
# -----------n_lstm_neuron: 8--------------
# Epoch 00305: early stopping
# # Finished Training...
# Train RMSE: 0.5631, Test RMSE: 0.2333
# Train MAPE: 0.0313, Test MAPE: 0.0196
# Train Dstat: 0.7108, Test Dstat: 0.7793
# -----------n_lstm_neuron: 16--------------
# Epoch 00318: early stopping
# # Finished Training...
# Train RMSE: 0.5705, Test RMSE: 0.2620
# Train MAPE: 0.0310, Test MAPE: 0.0253
# Train Dstat: 0.7380, Test Dstat: 0.7048
# -----------n_lstm_neuron: 24--------------
# Epoch 00303: early stopping
# # Finished Training...
# Train RMSE: 0.5937, Test RMSE: 0.2294
# Train MAPE: 0.0338, Test MAPE: 0.0202
# Train Dstat: 0.6935, Test Dstat: 0.7314
# -----------n_lstm_neuron: 32--------------
# Epoch 00259: early stopping
# # Finished Training...
# Train RMSE: 0.5650, Test RMSE: 0.2962
# Train MAPE: 0.0330, Test MAPE: 0.0298
# Train Dstat: 0.7001, Test Dstat: 0.7101
# -----------n_lstm_neuron: 40--------------
# Epoch 00315: early stopping
# # Finished Training...
# Train RMSE: 0.5608, Test RMSE: 0.2588
# Train MAPE: 0.0309, Test MAPE: 0.0246
# Train Dstat: 0.7241, Test Dstat: 0.7314
# -----------n_lstm_neuron: 48--------------
# Epoch 00278: early stopping
# # Finished Training...
# Train RMSE: 0.5514, Test RMSE: 0.2325
# Train MAPE: 0.0297, Test MAPE: 0.0197
# Train Dstat: 0.7507, Test Dstat: 0.7793
#
# -----------time steps: 21--------------
# -----------n_lstm_neuron: 4--------------
# Epoch 00489: early stopping
# # Finished Training...
# Train RMSE: 0.5715, Test RMSE: 0.2210
# Train MAPE: 0.0300, Test MAPE: 0.0188
# Train Dstat: 0.7452, Test Dstat: 0.7840
# -----------n_lstm_neuron: 8--------------
# Epoch 00319: early stopping
# # Finished Training...
# Train RMSE: 0.5694, Test RMSE: 0.2552
# Train MAPE: 0.0313, Test MAPE: 0.0245
# Train Dstat: 0.7219, Test Dstat: 0.7147
# -----------n_lstm_neuron: 16--------------
# Epoch 00274: early stopping
# # Finished Training...
# Train RMSE: 0.5759, Test RMSE: 0.2961
# Train MAPE: 0.0339, Test MAPE: 0.0299
# Train Dstat: 0.7026, Test Dstat: 0.6987
# -----------n_lstm_neuron: 24--------------
# Epoch 00279: early stopping
# # Finished Training...
# Train RMSE: 0.5916, Test RMSE: 0.2832
# Train MAPE: 0.0382, Test MAPE: 0.0277
# Train Dstat: 0.7073, Test Dstat: 0.7707
# -----------n_lstm_neuron: 32--------------
# Epoch 00313: early stopping
# # Finished Training...
# Train RMSE: 0.5848, Test RMSE: 0.2408
# Train MAPE: 0.0327, Test MAPE: 0.0216
# Train Dstat: 0.7246, Test Dstat: 0.7307
# -----------n_lstm_neuron: 40--------------
# Epoch 00281: early stopping
# # Finished Training...
# Train RMSE: 0.5989, Test RMSE: 0.2256
# Train MAPE: 0.0346, Test MAPE: 0.0193
# Train Dstat: 0.7086, Test Dstat: 0.7867
# -----------n_lstm_neuron: 48--------------
# Epoch 00297: early stopping
# # Finished Training...
# Train RMSE: 0.5583, Test RMSE: 0.2348
# Train MAPE: 0.0303, Test MAPE: 0.0203
# Train Dstat: 0.7498, Test Dstat: 0.7600
#
# # All Done!
