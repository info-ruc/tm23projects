# %%
import pymysql.cursors
import datetime
import pandas as pandas
import numpy as np
# Out:
# D:\Anaconda3\envs\tensorflow\lib\importlib\_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)
# D:\Anaconda3\envs\tensorflow\lib\importlib\_bootstrap.py:222: RuntimeWarning: numpy.dtype size changed, may indicate binary incompatibility. Expected 96, got 88
#   return f(*args, **kwds)

# %%
# 【函数说明】：把datetime转成字符串
def datetime_toString(dt):
    return dt.strftime("%Y-%m-%d")

# 【函数说明】：输入dataframe日期升序，日期字段名为date，价格字段名为price
# 填补最小日期到最大日期之间的缺失日期
# 返回：完整的dataframe
def fill_date(dataframe):
    df_plus = pandas.DataFrame() #空表，存储填充的缺失日期序列
    row = dataframe.head(1).copy(); #复制一行作为插入模板
    df_dates = dataframe['date'].tolist()  #数据日期转为列表
    date_start = df_dates[0] #初始时间
    for j in range(0, len(df_dates)):
        date_start_s = datetime_toString(date_start)   #日期转换为字符串类型，使日期可进行逻辑比较
        date_pre_s = datetime_toString(df_dates[j]) #j一直在累加
        # 如数据中日期列表与期望日期序列不相等，即存在缺失值执行while程序
        while (date_pre_s != date_start_s and date_pre_s > date_start_s): #忽略重复日期（最好前期有去重！）
            # print(date_pre_s + " != " + date_start_s + ", add " + date_start_s)
            row.loc[0, ('date',)] = date_start #passes a nested tuple of (slice(None),('one','second'))
            row.loc[0, ('price',)] = None
            df_plus = pandas.concat([df_plus, row]) #将缺失日期新的数据列表中
            date_start += datetime.timedelta(days=1) #日期加一
            date_start_s = datetime_toString(date_start)  
        date_start += datetime.timedelta(days=1) #日期加一
        
    # print("\n df_plus's shape: ", df_plus.shape, "\n", df_plus)
    dataframe = pandas.concat([dataframe, df_plus]) #将缺失日期加入数据列表中（尾部）
    dataframe = dataframe.sort_values(by=['date']) #重新排序
    
    return dataframe

# 【函数说明】：缺失值（价格数据）填充，价格字段名为price
# 返回：待插入的缺失序列（表结构）
def fill_empty_values(dataframe):
    # 方法一：获取缺失值所在行号
    empty_rows = np.where(dataframe.isna())[0] #查找缺失值所在位置
    print("\n缺失值行号：", empty_rows)

    # 缺失值填充：http://pandas.pydata.org/pandas-docs/stable/generated/pandas.DataFrame.interpolate.html#pandas.DataFrame.interpolate
    dataframe['price'] = dataframe['price'].interpolate('linear') #'linear': ignore the index and treat the values as equally spaced
    # print("\n缺失值填充：\n", dataframe)

    df_insert = pandas.DataFrame() #空表，存储填充的缺失日期序列（已填充缺失值）
    for j in range(0, len(empty_rows)): 
        row_insert = df_filled.iloc[[ empty_rows[j] ]]
        df_insert = pandas.concat([df_insert, row_insert]) #将缺失日期加入数据列表中
    # print("\n待插入的缺失序列：\n", df_insert)

    # 方法二：所有新增行索引为0，需去掉首行（更快，但不如方法一通用）
    # empty_rows_p = df_filled.loc[0]
    # empty_rows = empty_rows_p.iloc[1:len(empty_rows_p)] #查找缺失值所在位置
    # print("\n缺失值行\n：", empty_rows)
    
    return df_insert

# %%
# Connect to the database
connection = pymysql.connect(host='localhost',
                             user='root',
                             password='root',
                             db='farmsdata',
                             charset='utf8mb4',
                             cursorclass=pymysql.cursors.DictCursor)
try:
    with connection.cursor() as cursor:
        # Read a single record
        sql = "SELECT * FROM `apple` WHERE `bazaar` LIKE '%广州%' ORDER BY `date` ASC" #按日期升序，字段名要用倒引号
        cursor.execute(sql)
        result = cursor.fetchall()
        df = pandas.DataFrame(result) #转换成dataframe
        # print("df's shape: ", df.shape, "\n", df.head(30)) #打印前30行
        
        df_filled = fill_date(df)
        print("\n 【缺失日期填充（总表部分）】df_filled's shape:", df_filled.shape, "\n", df_filled.head(30))
        
        df_insert = fill_empty_values(df_filled)
        print("\n 【价格缺失值填充（待插入的缺失序列】df_insert's shape:", df_insert.shape, "\n", df_insert)
        
finally:
    connection.close()
# Out:
#  【缺失日期填充（总表部分）】df_filled's shape: (1668, 5)
#              bazaar        date farmsName    id  price
# 0   广东省广州市江南农副产品市场  2014-01-02      富士苹果    49  10.71
# 1   广东省广州市江南农副产品市场  2014-01-03      富士苹果   135  10.71
# 2   广东省广州市江南农副产品市场  2014-01-04      富士苹果   198  10.71
# 3   广东省广州市江南农副产品市场  2014-01-05      富士苹果   282  10.71
# 0   广东省广州市江南农副产品市场  2014-01-06      富士苹果    49    NaN
# 4   广东省广州市江南农副产品市场  2014-01-07      富士苹果   341  10.71
# 5   广东省广州市江南农副产品市场  2014-01-08      富士苹果   489  10.71
# 6   广东省广州市江南农副产品市场  2014-01-09      富士苹果   502  10.71
# 7   广东省广州市江南农副产品市场  2014-01-10      富士苹果   586  11.07
# 8   广东省广州市江南农副产品市场  2014-01-11      富士苹果   695  10.71
# 9   广东省广州市江南农副产品市场  2014-01-12      富士苹果   716  10.71
# 10  广东省广州市江南农副产品市场  2014-01-13      富士苹果   839  11.43
# 11  广东省广州市江南农副产品市场  2014-01-14      富士苹果   878  11.43
# 12  广东省广州市江南农副产品市场  2014-01-15      富士苹果   993  11.43
# 13  广东省广州市江南农副产品市场  2014-01-16      富士苹果  1018  11.43
# 14  广东省广州市江南农副产品市场  2014-01-17      富士苹果  1119  11.43
# 15  广东省广州市江南农副产品市场  2014-01-18      富士苹果  1181  11.43
# 16  广东省广州市江南农副产品市场  2014-01-19      富士苹果  1256  11.43
# 17  广东省广州市江南农副产品市场  2014-01-20      富士苹果  1322  11.43
# 18  广东省广州市江南农副产品市场  2014-01-21      富士苹果  1414  11.43
# 19  广东省广州市江南农副产品市场  2014-01-22      富士苹果  1474  11.43
# 20  广东省广州市江南农副产品市场  2014-01-23      富士苹果  1591  11.43
# 21  广东省广州市江南农副产品市场  2014-01-24      富士苹果  1610  11.43
# 22  广东省广州市江南农副产品市场  2014-01-25      富士苹果  1736  11.43
# 23  广东省广州市江南农副产品市场  2014-01-26      富士苹果  1791  11.43
# 24  广东省广州市江南农副产品市场  2014-01-27      富士苹果  1876  11.43
# 25  广东省广州市江南农副产品市场  2014-01-28      富士苹果  1937  12.14
# 0   广东省广州市江南农副产品市场  2014-01-29      富士苹果    49    NaN
# 0   广东省广州市江南农副产品市场  2014-01-30      富士苹果    49    NaN
# 0   广东省广州市江南农副产品市场  2014-01-31      富士苹果    49    NaN
#
# 缺失值行号： [   4   27   28   29   30   31   32   33   34   35   54   76   99  106
#   107  119  129  135  136  138  144  185  216  227  280  282  304  311
#   312  313  314  315  318  325  328  329  330  331  332  345  346  353
#   360  369  370  375  385  387  388  390  395  399  410  413  414  415
#   416  417  418  427  428  429  430  435  451  464  471  472  480  481
#   484  485  486  499  506  507  511  512  513  514  520  521  523  588
#   645  664  677  678  714  767  768  769  770  771  772  782  807  814
#   815  831  860  876  877  878 1008 1009 1014 1015 1016 1017 1018 1053
#  1090 1099 1109 1164 1165 1168 1185 1229 1289 1290 1291 1292 1293 1294
#  1295 1297 1298 1299 1301 1302 1303 1304 1305 1306 1307 1308 1309 1326
#  1341 1343 1347 1349 1362 1441 1443 1461 1475 1476 1508 1509 1510 1516
#  1526 1545 1558 1587 1590 1634 1640 1641 1648 1649 1650 1651 1652 1653
#  1654 1655]
#
#  【价格缺失值填充（待插入的缺失序列】df_insert's shape: (170, 5)
#              bazaar        date farmsName  id      price
# 0   广东省广州市江南农副产品市场  2014-01-06      富士苹果  49  10.710000
# 0   广东省广州市江南农副产品市场  2014-01-29      富士苹果  49  12.140000
# 0   广东省广州市江南农副产品市场  2014-01-30      富士苹果  49  12.140000
# 0   广东省广州市江南农副产品市场  2014-01-31      富士苹果  49  12.140000
# 0   广东省广州市江南农副产品市场  2014-02-01      富士苹果  49  12.140000
# 0   广东省广州市江南农副产品市场  2014-02-02      富士苹果  49  12.140000
# 0   广东省广州市江南农副产品市场  2014-02-03      富士苹果  49  12.140000
# 0   广东省广州市江南农副产品市场  2014-02-04      富士苹果  49  12.140000
# 0   广东省广州市江南农副产品市场  2014-02-05      富士苹果  49  12.140000
# 0   广东省广州市江南农副产品市场  2014-02-06      富士苹果  49  12.140000
# 0   广东省广州市江南农副产品市场  2014-02-25      富士苹果  49   6.790000
# 0   广东省广州市江南农副产品市场  2014-03-19      富士苹果  49  11.610000
# 0   广东省广州市江南农副产品市场  2014-04-11      富士苹果  49  11.250000
# 0   广东省广州市江南农副产品市场  2014-04-18      富士苹果  49  11.906667
# 0   广东省广州市江南农副产品市场  2014-04-19      富士苹果  49  12.383333
# 0   广东省广州市江南农副产品市场  2014-05-01      富士苹果  49  13.750000
# 0   广东省广州市江南农副产品市场  2014-05-11      富士苹果  49  15.000000
# 0   广东省广州市江南农副产品市场  2014-05-17      富士苹果  49  11.906667
# 0   广东省广州市江南农副产品市场  2014-05-18      富士苹果  49  12.383333
# 0   广东省广州市江南农副产品市场  2014-05-20      富士苹果  49  13.215000
# 0   广东省广州市江南农副产品市场  2014-05-26      富士苹果  49  13.930000
# 0   广东省广州市江南农副产品市场  2014-07-06      富士苹果  49  13.925000
# 0   广东省广州市江南农副产品市场  2014-08-06      富士苹果  49  13.395000
# 0   广东省广州市江南农副产品市场  2014-08-17      富士苹果  49  14.180000
# 0   广东省广州市江南农副产品市场  2014-10-09      富士苹果  49  15.000000
# 0   广东省广州市江南农副产品市场  2014-10-11      富士苹果  49  13.070000
# 0   广东省广州市江南农副产品市场  2014-11-02      富士苹果  49  10.500000
# 0   广东省广州市江南农副产品市场  2014-11-09      富士苹果  49  10.686667
# 0   广东省广州市江南农副产品市场  2014-11-10      富士苹果  49  10.663333
# 0   广东省广州市江南农副产品市场  2014-11-11      富士苹果  49  10.640000
# ..             ...         ...       ...  ..        ...
# 0   广东省广州市江南农副产品市场  2017-09-04      富士苹果  49   7.875000
# 0   广东省广州市江南农副产品市场  2017-09-06      富士苹果  49   8.000000
# 0   广东省广州市江南农副产品市场  2017-09-10      富士苹果  49   8.000000
# 0   广东省广州市江南农副产品市场  2017-09-12      富士苹果  49   7.775000
# 0   广东省广州市江南农副产品市场  2017-09-25      富士苹果  49   7.750000
# 0   广东省广州市江南农副产品市场  2017-12-13      富士苹果  49   7.050000
# 0   广东省广州市江南农副产品市场  2017-12-15      富士苹果  49   7.425000
# 0   广东省广州市江南农副产品市场  2018-01-02      富士苹果  49   6.875000
# 0   广东省广州市江南农副产品市场  2018-01-16      富士苹果  49   6.666667
# 0   广东省广州市江南农副产品市场  2018-01-17      富士苹果  49   6.583333
# 0   广东省广州市江南农副产品市场  2018-02-18      富士苹果  49   8.045000
# 0   广东省广州市江南农副产品市场  2018-02-19      富士苹果  49   8.340000
# 0   广东省广州市江南农副产品市场  2018-02-20      富士苹果  49   8.635000
# 0   广东省广州市江南农副产品市场  2018-02-26      富士苹果  49   8.375000
# 0   广东省广州市江南农副产品市场  2018-03-08      富士苹果  49   7.000000
# 0   广东省广州市江南农副产品市场  2018-03-27      富士苹果  49   8.050000
# 0   广东省广州市江南农副产品市场  2018-04-09      富士苹果  49   8.075000
# 0   广东省广州市江南农副产品市场  2018-05-08      富士苹果  49   7.375000
# 0   广东省广州市江南农副产品市场  2018-05-11      富士苹果  49   7.875000
# 0   广东省广州市江南农副产品市场  2018-06-24      富士苹果  49   7.500000
# 0   广东省广州市江南农副产品市场  2018-06-30      富士苹果  49   7.250000
# 0   广东省广州市江南农副产品市场  2018-07-01      富士苹果  49   7.250000
# 0   广东省广州市江南农副产品市场  2018-07-08      富士苹果  49   6.361111
# 0   广东省广州市江南农副产品市场  2018-07-09      富士苹果  49   6.472222
# 0   广东省广州市江南农副产品市场  2018-07-10      富士苹果  49   6.583333
# 0   广东省广州市江南农副产品市场  2018-07-11      富士苹果  49   6.694444
# 0   广东省广州市江南农副产品市场  2018-07-12      富士苹果  49   6.805556
# 0   广东省广州市江南农副产品市场  2018-07-13      富士苹果  49   6.916667
# 0   广东省广州市江南农副产品市场  2018-07-14      富士苹果  49   7.027778
# 0   广东省广州市江南农副产品市场  2018-07-15      富士苹果  49   7.138889
#
# [170 rows x 5 columns]

# %%
# 参考：https://blog.csdn.net/leo_sheng/article/details/83316285
